# %%
import json

data = []

with open("../data/problems_data.jsonl", "r", encoding="utf-8") as f:
    for line in f:
        data.append(json.loads(line))

print("Total problems:", len(data))

print(data[0], "\n")
print(data[8], "\n")
# Out:
# Total problems: 4112
# ...

# %%
set(item["problem_class"] for item in data)
# Out:
# {'easy', 'hard', 'medium'}
